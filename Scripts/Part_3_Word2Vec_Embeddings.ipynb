# %%
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd
import numpy as np
pd.set_option("display.max_colwidth", 200)

# %%
df = pd.read_pickle('/content/cleaned_tweets_v1.pkl')
df.head()
# Out:
#    label  \
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#
#                                                                                                                                  tweet  \
# 0     #fingerprint #Pregnancy Test https://goo.gl/h1MfQV #android #apps #beautiful #cute #health #igers #iphoneonly #iphonesia #iphone
# 1  Finally a transparant silicon case ^^ Thanks to my uncle :) #yay #Sony #Xperia #S #sonyexperias… http://instagram.com/p/YGEt5JC6JM/
# 2          We love this! Would you go? #talk #makememories #unplug #relax #iphone #smartphone #wifi #connect... http://fb.me/6N3LsUpCu
# 3                     I'm wired I know I'm George I was made that way ;) #iphone #cute #daventry #home http://instagr.am/p/Li_5_ujS4k/
# 4         What amazing service! Apple won't even talk to me about a question I have unless I pay them $19.95 for their stupid support!
#
#                                                                                                cleaned_tweets  \
# 0             fingerprint pregnancy test android apps beautiful cute health igers iphoneonly iphonesia iphone
# 1                                  finally transparant silicon case thanks uncle yay sony xperia sonyexperias
# 2                           love this would you talk makememories unplug relax iphone smartphone wifi connect
# 3                                                wired know george wa made that way iphone cute daventry home
# 4  what amazing service apple will not even talk about question have unless pay them for their stupid support
#
#                                                                   cleaned_tweets_without_stopwords
# 0  fingerprint pregnancy test android apps beautiful cute health igers iphoneonly iphonesia iphone
# 1                       finally transparant silicon case thanks uncle yay sony xperia sonyexperias
# 2                               love talk makememories unplug relax iphone smartphone wifi connect
# 3                                                  wired know george way iphone cute daventry home
# 4                                    amazing service apple talk question unless pay stupid support

# %% [markdown]
# # New Section

# %%
df.shape
# Out:
# (7920, 4)

# %%
df.columns
# Out:
# Index(['label', 'tweet', 'cleaned_tweets', 'cleaned_tweets_without_stopwords'], dtype='object')

# %%
df['label'].value_counts()
# Out:
# label
# 1    5894
# 0    2026
# Name: count, dtype: int64

# %%
# splitting the data into x and y
x = df[['cleaned_tweets_without_stopwords']]
y = df['label']

print(y.head())
print()
print(x.head())
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: label, dtype: int64
#
#                                                                   cleaned_tweets_without_stopwords
# 0  fingerprint pregnancy test android apps beautiful cute health igers iphoneonly iphonesia iphone
# 1                       finally transparant silicon case thanks uncle yay sony xperia sonyexperias
# 2                               love talk makememories unplug relax iphone smartphone wifi connect
# 3                                                  wired know george way iphone cute daventry home
# 4                                    amazing service apple talk question unless pay stupid support

# %%
# splitting the data into training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (6336, 1) (1584, 1) (6336,) (1584,)

# %%
# importing basic nlp cleaning method prior applying word2vec
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

def clean(doc):
    regex = "[^a-zA-Z]"
    doc = re.sub(regex, " ", doc)
    doc = doc.lower()
    tokens = nltk.word_tokenize(doc)
    stop_words = list(set(stopwords.words('english')))
    custom_stop_words = ["i", "a", "h","iO","i0","1o","10","lo","l0","io ", "i0 "]
    stop_words = stop_words + custom_stop_words
    filterted_tokens = [word for word in tokens if word not in stop_words]
    lemmatized_token = [lemmatizer.lemmatize(token) for token in filterted_tokens]
    return " ".join(lemmatized_token)

# %%
x_train.head()
# Out:
#                                                  cleaned_tweets_without_stopwords
# 7544                       fucking apple iphone fucking lost fuck apple die apple
# 3918                                         sweet case cute iphoneography iphone
# 7839        bamboo vocation newyear trip thailand khaoko ilce sony vsco snapspeed
# 5673            given today samsung inch livingroom home black white yay thankyou
# 5966  soft grip battery case iphone powerplus perfect case fit snugly distributor

# %%
x_test.head()
# Out:
#                                                                                                                                                         cleaned_tweets_without_stopwords
# 2221                                                                                                                                 moby buy cool gift today samsung iphone sony tablet
# 3794                                                                                                                                                        restore ipod dumb ughh apple
# 823   preparing release foldable phone filed patten self repairing screen function apple influencer samsunggalaxy tech photooftheday money samsung save gadget tryit technology motorola
# 686                                                                                                                   watchdog ubisoft playstation sony midnight gaming gamer videogames
# 7081                                                                                                                  working saturday morning nofilter dreamjob sun apple sony poliedro

# %%
x_train['tokenised_sentences'] = x_train['cleaned_tweets_without_stopwords'].apply(lambda doc: doc.split())
x_train.head()
# Out:
#                                                  cleaned_tweets_without_stopwords  \
# 7544                       fucking apple iphone fucking lost fuck apple die apple
# 3918                                         sweet case cute iphoneography iphone
# 7839        bamboo vocation newyear trip thailand khaoko ilce sony vsco snapspeed
# 5673            given today samsung inch livingroom home black white yay thankyou
# 5966  soft grip battery case iphone powerplus perfect case fit snugly distributor
#
#                                                                           tokenised_sentences
# 7544                         [fucking, apple, iphone, fucking, lost, fuck, apple, die, apple]
# 3918                                               [sweet, case, cute, iphoneography, iphone]
# 7839         [bamboo, vocation, newyear, trip, thailand, khaoko, ilce, sony, vsco, snapspeed]
# 5673             [given, today, samsung, inch, livingroom, home, black, white, yay, thankyou]
# 5966  [soft, grip, battery, case, iphone, powerplus, perfect, case, fit, snugly, distributor]

# %%
x_test['tokenised_sentences'] = x_test['cleaned_tweets_without_stopwords'].apply(lambda doc: doc.split())
x_test.head()
# Out:
#                                                                                                                                                         cleaned_tweets_without_stopwords  \
# 2221                                                                                                                                 moby buy cool gift today samsung iphone sony tablet
# 3794                                                                                                                                                        restore ipod dumb ughh apple
# 823   preparing release foldable phone filed patten self repairing screen function apple influencer samsunggalaxy tech photooftheday money samsung save gadget tryit technology motorola
# 686                                                                                                                   watchdog ubisoft playstation sony midnight gaming gamer videogames
# 7081                                                                                                                  working saturday morning nofilter dreamjob sun apple sony poliedro
#
#                                                                                                                                                                                           tokenised_sentences
# 2221                                                                                                                                            [moby, buy, cool, gift, today, samsung, iphone, sony, tablet]
# 3794                                                                                                                                                                       [restore, ipod, dumb, ughh, apple]
# 823   [preparing, release, foldable, phone, filed, patten, self, repairing, screen, function, apple, influencer, samsunggalaxy, tech, photooftheday, money, samsung, save, gadget, tryit, technology, moto...
# 686                                                                                                                               [watchdog, ubisoft, playstation, sony, midnight, gaming, gamer, videogames]
# 7081                                                                                                                             [working, saturday, morning, nofilter, dreamjob, sun, apple, sony, poliedro]

# %% [markdown]
# # Applying Feature Transformation approach - Word2Vec

# %%
"""
## Capture the semantic relationship between words
## Embedding - dense vector (50-300 dimensions)

### Word2Vec Architecture

a) CBOW - Continous Bag of Words
b) Skip-Gram

1) input layer
2) hidden layer
3) output layer

4) Word Embedding
5) Context Window
6) Negative Sampling method
7) Hierarchical softmax method
8) Cosine Similarity

### Significance of Word2Vec
a) Semantic similarity
b) Efficient Learning
c) Transfer Learning
"""
# Out:
# '\n## Capture the semantic relationship between words\n## Embedding - dense vector (50-300 dimensions)\n\n### Word2Vec Architecture\n\na) CBOW - Continous Bag of Words\nb) Skip-Gram\n\n1) input layer \n2) hidden layer\n3) output layer\n\n4) Word Embedding\n5) Context Window\n6) Negative Sampling method\n7) Hierarchical softmax method\n8) Cosine Similarity\n\n### Significance of Word2Vec\na) Semantic similarity\nb) Efficient Learning\nc) Transfer Learning\n'

# %%
from gensim.models import Word2Vec

# %%
# %time word_vec = Word2Vec(x_train['tokenised_sentences'], vector_size=300, min_count=1)
print(word_vec)
# Out:
# CPU times: user 1.41 s, sys: 57.6 ms, total: 1.47 s
# Wall time: 938 ms
# Word2Vec<vocab=13262, vector_size=300, alpha=0.025>

# %%
13262 * 300
# Out:
# 3978600

# %%
x_train.shape
# Out:
# (6336, 2)

# %%
word_vec.corpus_count
# Out:
# 6336

# %%
word_vec.vector_size
# Out:
# 300

# %%
word_vec.wv.index_to_key
# Out:
# ['iphone',
#  'apple',
#  'samsung',
#  'new',
#  'phone',
#  'sony',
#  'follow',
#  'pic',
#  'like',
#  'ipad',
#  'love',
#  'day',
#  'life',
#  'android',
#  'io',
#  'photo',
#  'galaxy',
#  'case',
#  'gain',
#  'cute',
#  'today',
#  'got',
#  'photography',
#  'fun',
#  'music',
#  'news',
#  'app',
#  'time',
#  'instagood',
#  'smile',
#  'happy',
#  'funny',
#  'birthday',
#  'beautiful',
#  'ipod',
#  'lol',
#  'work',
#  'fashion',
#  'make',
#  'game',
#  'girl',
#  'itunes',
#  'finally',
#  'photooftheday',
#  'tech',
#  'friend',
#  'update',
#  'iphonex',
#  'apps',
#  'good',
#  'want',
#  'amazing',
#  'sougofollow',
#  'selfie',
#  'follower',
#  'thanks',
#  'note',
#  'baby',
#  'sale',
#  'gift',
#  'fuck',
#  'mac',
#  'year',
#  'fail',
#  'look',
#  'rts',
#  'hate',
#  'igers',
#  'going',
#  'camera',
#  'free',
#  'art',
#  'home',
#  'fucking',
#  'iphonesia',
#  'family',
#  'charger',
#  'best',
#  'cool',
#  'christmas',
#  'iphoneonly',
#  'live',
#  'smartphone',
#  'health',
#  'summer',
#  'hour',
#  'white',
#  'need',
#  'suck',
#  'minute',
#  'thing',
#  'night',
#  'laptop',
#  'plus',
#  'nature',
#  'picoftheday',
#  'mobile',
#  'macbook',
#  'window',
#  'sexy',
#  'screen',
#  'know',
#  'color',
#  'product',
#  'money',
#  'buy',
#  'thank',
#  'awesome',
#  'accessory',
#  'motorola',
#  'wish',
#  'black',
#  'store',
#  'great',
#  'followme',
#  'nice',
#  'style',
#  'download',
#  'instamood',
#  'old',
#  'excited',
#  'guy',
#  'beauty',
#  'computer',
#  'say',
#  'really',
#  'people',
#  'use',
#  'pink',
#  'morning',
#  'hey',
#  'picture',
#  'retweet',
#  'sweet',
#  'boy',
#  'technology',
#  'toy',
#  'kid',
#  'right',
#  'video',
#  'pretty',
#  'job',
#  'battery',
#  'fuckyou',
#  'world',
#  'red',
#  'instadaily',
#  'watch',
#  'dog',
#  'playstation',
#  'nokia',
#  'offer',
#  'happiness',
#  'google',
#  'stupid',
#  'week',
#  'blue',
#  'count',
#  'text',
#  'let',
#  'travel',
#  'quote',
#  'shopping',
#  'food',
#  'sunday',
#  'cover',
#  'gaming',
#  'capetown',
#  'tablet',
#  'working',
#  'big',
#  'sun',
#  'laugh',
#  'gadget',
#  'getting',
#  'song',
#  'customer',
#  'think',
#  'instapic',
#  'design',
#  'cat',
#  'friday',
#  'book',
#  'check',
#  'trying',
#  'rhyme',
#  'present',
#  'tl',
#  'sunset',
#  'headphone',
#  'yay',
#  'followback',
#  'come',
#  'wow',
#  'hello',
#  'xperia',
#  'image',
#  'appstore',
#  'lost',
#  'surf',
#  'green',
#  'sup',
#  'deal',
#  'way',
#  'weekend',
#  'wait',
#  'month',
#  'gold',
#  'macbookpro',
#  'blackberry',
#  'beach',
#  'hot',
#  'flower',
#  'newyear',
#  'heart',
#  'valentine',
#  'sky',
#  'iphoneography',
#  'face',
#  'pro',
#  'upgrade',
#  'hard',
#  'holiday',
#  'twitch',
#  'charge',
#  'hateapple',
#  'share',
#  'play',
#  'dear',
#  'problem',
#  'amazon',
#  'bought',
#  'better',
#  'service',
#  'fix',
#  'dating',
#  'tweegram',
#  'siri',
#  'using',
#  'user',
#  'yeah',
#  'party',
#  'yes',
#  'try',
#  'god',
#  'man',
#  'blog',
#  'welcome',
#  'word',
#  'wifi',
#  'deleted',
#  'start',
#  'insta',
#  'coming',
#  'gamer',
#  'swag',
#  'bestprice',
#  'vsco',
#  'updated',
#  'crazy',
#  'discount',
#  'moment',
#  'message',
#  'random',
#  'oneplus',
#  'newphone',
#  'model',
#  'car',
#  'enjoy',
#  'usa',
#  'tbt',
#  'came',
#  'shop',
#  'took',
#  'support',
#  'instago',
#  'light',
#  'saturday',
#  'little',
#  'haha',
#  'mini',
#  'microsoft',
#  'reason',
#  'tab',
#  'seriously',
#  'early',
#  'company',
#  'miss',
#  'monday',
#  'shit',
#  'bad',
#  'ago',
#  'spring',
#  'fresh',
#  'code',
#  'ready',
#  'available',
#  'contact',
#  'power',
#  'movie',
#  'help',
#  'cable',
#  'hair',
#  'pay',
#  'switch',
#  'tweet',
#  'trip',
#  'nofilter',
#  'device',
#  'turn',
#  'house',
#  'mom',
#  'password',
#  'loving',
#  'phonecase',
#  'waiting',
#  'care',
#  'youtube',
#  'feel',
#  'coffee',
#  'change',
#  'win',
#  'break',
#  'imessage',
#  'long',
#  'galaxynote',
#  'teamfollowback',
#  'stop',
#  'single',
#  'fan',
#  'college',
#  'dad',
#  'geek',
#  'blessed',
#  'edge',
#  'broken',
#  'gay',
#  'tell',
#  'lock',
#  'london',
#  'piece',
#  'number',
#  'feature',
#  'business',
#  'taken',
#  'iphones',
#  'kiss',
#  'steve',
#  'making',
#  'followsunday',
#  'sad',
#  'instalove',
#  'sister',
#  'restore',
#  'real',
#  'arrived',
#  'worst',
#  'portrait',
#  'steemit',
#  'joy',
#  'soon',
#  'air',
#  'nyc',
#  'couple',
#  'tree',
#  'gratitude',
#  'india',
#  'instalike',
#  'sonylens',
#  'feeling',
#  'sonyphotography',
#  'thailand',
#  'husband',
#  'relationship',
#  'italy',
#  'sleep',
#  'school',
#  'tomorrow',
#  'pie',
#  'woman',
#  'favorite',
#  'fast',
#  'hope',
#  'decor',
#  'gear',
#  'relax',
#  'wedding',
#  'fruit',
#  'software',
#  'card',
#  'broke',
#  'order',
#  'water',
#  'actually',
#  'stuff',
#  'fit',
#  'popular',
#  'sync',
#  'pet',
#  'daughter',
#  'unlocked',
#  'sound',
#  'sonya',
#  'flash',
#  'used',
#  'ugh',
#  'email',
#  'story',
#  'garden',
#  'instahub',
#  'gone',
#  'send',
#  'button',
#  'vocation',
#  'inch',
#  'khaoko',
#  'shotoniphone',
#  'ilce',
#  'smart',
#  'igdaily',
#  'annoying',
#  'memory',
#  'florida',
#  'luxury',
#  'pop',
#  'looking',
#  'eye',
#  'healthy',
#  'version',
#  'pc',
#  'mirror',
#  'beat',
#  'city',
#  'imac',
#  'cellphone',
#  'lifestyle',
#  'snapspeed',
#  'jun',
#  'brother',
#  'perfect',
#  'run',
#  'space',
#  'verizon',
#  'giving',
#  'nike',
#  'puppy',
#  'charging',
#  'pissed',
#  'map',
#  'brand',
#  'newyork',
#  'psn',
#  'cloud',
#  'click',
#  'peace',
#  'cake',
#  'crap',
#  'rock',
#  'charm',
#  'playing',
#  'japan',
#  'thought',
#  'fixed',
#  'entrepreneur',
#  'orange',
#  'away',
#  'wallpaper',
#  'xbox',
#  'film',
#  'instacool',
#  'said',
#  'giveawaypic',
#  'makeup',
#  'repair',
#  'yesterday',
#  'photofeed',
#  'mother',
#  'blackandwhite',
#  'sure',
#  'sonyphoto',
#  'xperiaz',
#  'kindle',
#  'unitedstate',
#  'guitarplayer',
#  'fact',
#  'team',
#  'hand',
#  'lot',
#  'taking',
#  'bestoftheday',
#  'saying',
#  'animal',
#  'get',
#  'exquisite',
#  'strap',
#  'bit',
#  'squishy',
#  'link',
#  'drink',
#  'reallyreal',
#  'decided',
#  'wtf',
#  'min',
#  'data',
#  'tuesday',
#  'super',
#  'boyfriend',
#  'go',
#  'goodnight',
#  'icloud',
#  'keyboard',
#  'listen',
#  'likeforlike',
#  'forever',
#  'dead',
#  'emoji',
#  'small',
#  'delete',
#  'ipadmini',
#  'htc',
#  'applewatch',
#  'post',
#  'miami',
#  'sea',
#  'april',
#  'idea',
#  'date',
#  'sport',
#  'rose',
#  'shot',
#  'skin',
#  'believe',
#  'literally',
#  'canon',
#  'account',
#  'true',
#  'king',
#  'set',
#  'talk',
#  'end',
#  'went',
#  'facetime',
#  'latest',
#  'daddy',
#  'guess',
#  'iphonecase',
#  'different',
#  'release',
#  'line',
#  'dream',
#  'sonyphotos',
#  'proud',
#  'wife',
#  'feed',
#  'learn',
#  'truth',
#  'xmas',
#  'rain',
#  'fml',
#  'future',
#  'ootd',
#  'foodporn',
#  'vaio',
#  'lens',
#  'photographer',
#  'tattoo',
#  'digital',
#  'child',
#  'console',
#  'usb',
#  'zeeland',
#  'price',
#  'keep',
#  'photobooth',
#  'buying',
#  'street',
#  'inlove',
#  'evening',
#  'sick',
#  'crash',
#  'purpose',
#  'sorority',
#  'trump',
#  'thankyou',
#  'adorable',
#  'issue',
#  'fitness',
#  'purchase',
#  'touch',
#  'running',
#  'goal',
#  'market',
#  'simple',
#  'bye',
#  'mommy',
#  'sprint',
#  'special',
#  'visit',
#  'yummy',
#  'longer',
#  'mind',
#  'delicious',
#  'bright',
#  'half',
#  'earphone',
#  'smartphones',
#  'november',
#  'prophet',
#  'dessert',
#  'past',
#  'sim',
#  'wall',
#  'high',
#  'later',
#  'throw',
#  'stevejobs',
#  'mean',
#  'sonyalpha',
#  'second',
#  'left',
#  'question',
#  'yum',
#  'sunny',
#  'bored',
#  'far',
#  'vintage',
#  'chocolate',
#  'kind',
#  'gorgeous',
#  'stuck',
#  'cell',
#  'cut',
#  'cracked',
#  'sorry',
#  'adventure',
#  'men',
#  'speaker',
#  'answer',
#  'uae',
#  'slow',
#  'dance',
#  'shoot',
#  'shitty',
#  'type',
#  'tonight',
#  'angry',
#  'samsunggalaxys',
#  'bug',
#  'shoppinglist',
#  'bestfriend',
#  'porn',
#  'calendar',
#  'photograph',
#  'poem',
#  'chill',
#  'silver',
#  'producer',
#  'reset',
#  'snow',
#  'banana',
#  'thankful',
#  'room',
#  'instaphoto',
#  'winter',
#  'nikon',
#  'dropped',
#  'california',
#  'load',
#  'experience',
#  'completely',
#  'fucked',
#  'tired',
#  'passion',
#  'die',
#  'artist',
#  'canada',
#  'unique',
#  'tag',
#  'humanity',
#  'blogger',
#  'ask',
#  'zoom',
#  'starbucks',
#  'march',
#  'original',
#  'info',
#  'office',
#  'ipads',
#  'att',
#  'valentinesday',
#  'bird',
#  'library',
#  'ordered',
#  'sent',
#  'patent',
#  'piano',
#  'save',
#  'weather',
#  'open',
#  'wrong',
#  'webstagram',
#  'freaking',
#  'boostmobile',
#  'goodbye',
#  'forgot',
#  'fall',
#  'creative',
#  'vscocam',
#  'finger',
#  'lion',
#  'unlock',
#  'stock',
#  'bring',
#  'review',
#  'indonesia',
#  'delivery',
#  'america',
#  'stand',
#  'stay',
#  'cold',
#  'cook',
#  'totally',
#  'replaced',
#  'middle',
#  'dress',
#  'drive',
#  'online',
#  'gave',
#  'chat',
#  'eat',
#  'june',
#  'told',
#  'soul',
#  'january',
#  'everyday',
#  'bed',
#  'deleting',
#  'moto',
#  'tshirt',
#  'mode',
#  'silly',
#  'genius',
#  'level',
#  'blow',
#  'trend',
#  'colorful',
#  'mail',
#  'babe',
#  'chilling',
#  'iphonephotography',
#  'sell',
#  'ebay',
#  'osx',
#  'million',
#  'december',
#  'purple',
#  'flag',
#  'bestfriends',
#  'file',
#  'gopro',
#  'magic',
#  'dual',
#  'brazil',
#  'blackfriday',
#  'february',
#  'replace',
#  'applestore',
#  'colour',
#  'display',
#  'event',
#  'potd',
#  'shooting',
#  'playlist',
#  'player',
#  'read',
#  'lunch',
#  'join',
#  'europe',
#  'choose',
#  'mountain',
#  'lip',
#  'ear',
#  'drop',
#  'daily',
#  'spotify',
#  'singer',
#  'added',
#  'effect',
#  'vacation',
#  'take',
#  'paris',
#  'storage',
#  'droid',
#  'redbubble',
#  'voice',
#  'horse',
#  'glad',
#  'aliusaexpress',
#  'mood',
#  'bos',
#  'seeing',
#  'phonecases',
#  'juice',
#  'nail',
#  'wonder',
#  'view',
#  'bluetooth',
#  'easter',
#  'bull',
#  'tmobile',
#  'blonde',
#  'yellow',
#  'reposting',
#  'dinner',
#  'followtrick',
#  'anymore',
#  'foe',
#  'hdr',
#  'park',
#  'lose',
#  'wonderful',
#  'install',
#  'tried',
#  'videogames',
#  'useless',
#  'edm',
#  'asshole',
#  'smartwatch',
#  'jailbreak',
#  'started',
#  'rid',
#  'able',
#  'yolo',
#  'omg',
#  'failed',
#  'newtoy',
#  'goodmorning',
#  'surprise',
#  'tagsforlikes',
#  'gamers',
#  'wiped',
#  'spend',
#  'easy',
#  'bbm',
#  'dope',
#  'sticker',
#  'princess',
#  'cuz',
#  'lady',
#  'conversation',
#  'charged',
#  'wireless',
#  'samsunggalaxy',
#  'shipping',
#  'bar',
#  'cousin',
#  'merrychristmas',
#  'romance',
#  'died',
#  'candy',
#  'okay',
#  'connect',
#  'autumn',
#  'low',
#  'dark',
#  'upgraded',
#  'internet',
#  'social',
#  'wild',
#  'merry',
#  'catch',
#  'marketing',
#  'icecream',
#  'worse',
#  'decides',
#  'sing',
#  'planet',
#  'minion',
#  'place',
#  'zazzle',
#  'girlfriend',
#  'sweden',
#  'factory',
#  'key',
#  'nowplaying',
#  'security',
#  'lte',
#  'metroman',
#  'ignation',
#  'teamandroid',
#  'nascar',
#  'spawn',
#  'bitch',
#  'block',
#  'kawaii',
#  'spent',
#  'weekday',
#  'charity',
#  'september',
#  'listening',
#  'ride',
#  'satisfied',
#  'crappy',
#  'self',
#  'receive',
#  'telling',
#  'collection',
#  'tip',
#  'thanksgiving',
#  'theme',
#  'ball',
#  'lenovo',
#  'lucky',
#  'hellokitty',
#  'thursday',
#  'updating',
#  'filter',
#  'bro',
#  'launch',
#  'watching',
#  'inspiration',
#  'till',
#  'sketch',
#  'human',
#  'maybe',
#  'nearly',
#  'liverpool',
#  'jesus',
#  'worth',
#  'tasty',
#  'rii',
#  'queen',
#  'breakfast',
#  'fine',
#  'idiot',
#  'streetphotography',
#  'starting',
#  'credit',
#  'october',
#  'huge',
#  'series',
#  'machine',
#  'medium',
#  'needed',
#  'leaf',
#  'search',
#  'gallery',
#  'possible',
#  'duo',
#  'electronics',
#  'smallbiz',
#  'michelle',
#  'agree',
#  'reading',
#  'macbookair',
#  'cash',
#  'person',
#  'netflix',
#  'backup',
#  'glass',
#  'sunglass',
#  'followus',
#  'lake',
#  'cost',
#  'iii',
#  'newappstore',
#  'kill',
#  'track',
#  'applesucks',
#  'crashing',
#  'prime',
#  'error',
#  'loud',
#  'datingadvice',
#  'idol',
#  'supply',
#  'access',
#  'yousuck',
#  'innovation',
#  'apparently',
#  'shine',
#  'radio',
#  'complete',
#  'entire',
#  'american',
#  'course',
#  'appointment',
#  'alive',
#  'cooking',
#  'draw',
#  'vlog',
#  'zeta',
#  'decision',
#  'late',
#  'iphonecases',
#  'son',
#  'ring',
#  'chinese',
#  'commercial',
#  'hashtag',
#  ...]

# %%
def get_document_vector(doc, model):
  tokens = [word for word in doc if word in model]
  if tokens:
    doc_embedding = np.mean(model[tokens], axis=0)
  else:
    doc_embedding = np.zeros(model.vector_size)
  return doc_embedding

# %%
x_train['w2v_doc_embedding'] = x_train['tokenised_sentences'].apply(lambda doc: get_document_vector(doc, word_vec.wv))

# %%
x_train.head()
# Out:
#                                                  cleaned_tweets_without_stopwords  \
# 7544                       fucking apple iphone fucking lost fuck apple die apple
# 3918                                         sweet case cute iphoneography iphone
# 7839        bamboo vocation newyear trip thailand khaoko ilce sony vsco snapspeed
# 5673            given today samsung inch livingroom home black white yay thankyou
# 5966  soft grip battery case iphone powerplus perfect case fit snugly distributor
#
#                                                                           tokenised_sentences  \
# 7544                         [fucking, apple, iphone, fucking, lost, fuck, apple, die, apple]
# 3918                                               [sweet, case, cute, iphoneography, iphone]
# 7839         [bamboo, vocation, newyear, trip, thailand, khaoko, ilce, sony, vsco, snapspeed]
# 5673             [given, today, samsung, inch, livingroom, home, black, white, yay, thankyou]
# 5966  [soft, grip, battery, case, iphone, powerplus, perfect, case, fit, snugly, distributor]
#
#                                                                                                                                                                                             w2v_doc_embedding
# 7544  [0.10904018, 0.4422333, -0.06355248, 0.18067737, -0.07075185, -0.49178082, 0.45827734, 1.0946965, 0.1061438, -0.27378878, 0.1408419, -0.35934407, -0.1168069, -0.03384682, -0.18869428, -0.27566332,...
# 3918  [0.10670489, 0.365905, -0.053823225, 0.15552959, -0.06294916, -0.44688863, 0.41107702, 0.9886174, 0.08370793, -0.24525985, 0.10891942, -0.31216264, -0.08813124, -0.029887468, -0.1608086, -0.247999...
# 7839  [0.04010067, 0.16212907, -0.022837475, 0.065650575, -0.028646264, -0.17816392, 0.16534826, 0.39958256, 0.03534897, -0.09689092, 0.051683627, -0.13226894, -0.044564597, -0.011706686, -0.06866376, -...
# 5673  [0.056507833, 0.228713, -0.029853532, 0.09165266, -0.03850908, -0.24799395, 0.22904718, 0.5550545, 0.05485321, -0.135446, 0.07885091, -0.18952033, -0.0663193, -0.012733105, -0.09599836, -0.1408234...
# 5966  [0.04913728, 0.1693698, -0.024648637, 0.07190624, -0.027800852, -0.20786975, 0.1888496, 0.4566024, 0.03907989, -0.11428294, 0.051610734, -0.1434694, -0.041360952, -0.012017837, -0.0746774, -0.1143...

# %%
x_test['w2v_doc_embedding'] = x_test['tokenised_sentences'].apply(lambda doc: get_document_vector(doc, word_vec.wv))

# %%
x_test.head()
# Out:
#                                                                                                                                                         cleaned_tweets_without_stopwords  \
# 2221                                                                                                                                 moby buy cool gift today samsung iphone sony tablet
# 3794                                                                                                                                                        restore ipod dumb ughh apple
# 823   preparing release foldable phone filed patten self repairing screen function apple influencer samsunggalaxy tech photooftheday money samsung save gadget tryit technology motorola
# 686                                                                                                                   watchdog ubisoft playstation sony midnight gaming gamer videogames
# 7081                                                                                                                  working saturday morning nofilter dreamjob sun apple sony poliedro
#
#                                                                                                                                                                                           tokenised_sentences  \
# 2221                                                                                                                                            [moby, buy, cool, gift, today, samsung, iphone, sony, tablet]
# 3794                                                                                                                                                                       [restore, ipod, dumb, ughh, apple]
# 823   [preparing, release, foldable, phone, filed, patten, self, repairing, screen, function, apple, influencer, samsunggalaxy, tech, photooftheday, money, samsung, save, gadget, tryit, technology, moto...
# 686                                                                                                                               [watchdog, ubisoft, playstation, sony, midnight, gaming, gamer, videogames]
# 7081                                                                                                                             [working, saturday, morning, nofilter, dreamjob, sun, apple, sony, poliedro]
#
#                                                                                                                                                                                             w2v_doc_embedding
# 2221  [0.10592808, 0.39877066, -0.056871217, 0.16215344, -0.06669878, -0.44979033, 0.41716608, 1.0057712, 0.093354285, -0.24852265, 0.12735455, -0.33308443, -0.10700337, -0.027982507, -0.16919407, -0.25...
# 3794  [0.06129812, 0.26329464, -0.037120182, 0.104905605, -0.04158906, -0.28122175, 0.26317486, 0.626201, 0.06191513, -0.15508817, 0.086881235, -0.20973516, -0.07302944, -0.017649252, -0.11000731, -0.15...
# 823   [0.053042304, 0.24334298, -0.03678512, 0.078813106, -0.031064428, -0.24313839, 0.23846674, 0.5575647, 0.05607783, -0.14713919, 0.0883793, -0.1933668, -0.060884576, -0.02436373, -0.100825824, -0.14...
# 686   [0.054687977, 0.2399372, -0.03392419, 0.09128714, -0.038643207, -0.25578597, 0.23841077, 0.5736857, 0.053922478, -0.1408017, 0.08004251, -0.19396956, -0.06897543, -0.017733455, -0.10255063, -0.145...
# 7081  [0.081314616, 0.34338775, -0.04594492, 0.13624294, -0.054900922, -0.36783323, 0.34190074, 0.82311726, 0.07788979, -0.20246853, 0.11329995, -0.27627012, -0.096559845, -0.023390234, -0.14536107, -0....

# %% [markdown]
# # Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
# %time rf.fit(list(x_train['w2v_doc_embedding']), y_train)
y_pred = rf.predict(list(x_test['w2v_doc_embedding']))
print(y_pred)

from sklearn import metrics

print(f'Model Accuracy : {metrics.accuracy_score(y_test, y_pred)} ')
print()
print(f"Model's Classification Performance : {metrics.classification_report(y_test, y_pred)}")
# Out:
# CPU times: user 12.9 s, sys: 27 ms, total: 12.9 s
# Wall time: 13 s
# [1 0 1 ... 1 0 1]
# Model Accuracy : 0.7954545454545454
#
# Model's Classification Performance :               precision    recall  f1-score   support
#
#            0       0.64      0.45      0.53       405
#            1       0.83      0.92      0.87      1179
#
#     accuracy                           0.80      1584
#    macro avg       0.74      0.68      0.70      1584
# weighted avg       0.78      0.80      0.78      1584

# %% [markdown]
# # Agenda for tomorrow :
# # LSTM/GRU - long short term memory
# # CNN Model
# # Transformers
